# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])
print(np.sum(arr))
# Out:
# 21

# %%
np.mean(arr)
# Out:
# np.float64(3.5)

# %%
np.median(arr)
# Out:
# np.float64(3.5)

# %%
np.std(arr) # here std -> how spead our data is
# Out:
# np.float64(1.707825127659933)

# %%
np.var(arr)
# Out:
# np.float64(2.9166666666666665)

# %%
np.min(arr)
# Out:
# np.int64(1)

# %%
np.max(arr)
# Out:
# np.int64(6)

# %%
matrix = np.array([[1,2,4],
                   [4,5,6],
                   [7,8,9]])
np.sum(matrix, axis =0)
# Out:
# array([12, 15, 19])

# %%
np.sum(matrix, axis =1)
# Out:
# array([ 7, 15, 24])

# %%
# Comulative Operations -> running total
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
print(np.cumsum(arr))
# Out:
# [ 1  3  6 10 15 21]

# %%
print(np.cumprod(arr))
# Out:
# [  1   2   6  24 120 720]
