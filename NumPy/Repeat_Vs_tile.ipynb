# %%
import numpy as np

# %%
arr = np.array([1,2,3])
print(np.repeat(arr,2)) # here 2 -> how many times we need to repeat
# Out:
# [1 1 2 2 3 3]

# %%
# tile -> repeat whole array 
arr = np.array([1,2,3])
print(np.tile(arr,2))
# Out:
# [1 2 3 1 2 3]
