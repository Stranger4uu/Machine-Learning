# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6,7])
arr
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
lst = ["yash",1,2.4,2]
arr = np.array(lst)
arr
# Out:
# array(['yash', '1', '2.4', '2'], dtype='<U32')

# %%
array = np.array([2,3,4,5,])
array
# Out:
# array([2, 3, 4, 5])

# %%
array.dtype
# Out:
# dtype('int64')

# %%
array = np.array([2,3,4,5,], dtype = np.float64)
array
# Out:
# array([2., 3., 4., 5.])

# %%
array.dtype
# Out:
# dtype('float64')

# %%
array = np.array([2.5,3.14,4.54,5.2], dtype = np.int64 )
array
# Out:
# array([2, 3, 4, 5])

# %%
array.dtype
# Out:
# dtype('int64')

# %%
#typecasting

# %%
arr = np.array([2,3,5,7,5])
arr
# Out:
# array([2, 3, 5, 7, 5])

# %%
new_arr = arr.astype(np.float64)
new_arr
# Out:
# array([2., 3., 5., 7., 5.])

# %%
new_arr.dtype
# Out:
# dtype('float64')

# %%
new_arr2 = new_arr.astype(np.int64)
new_arr2
# Out:
# array([2, 3, 5, 7, 5])

# %%
#Typecasting_errors

# %%
array = np.array(["2","Yash","4"])
array
# Out:
# array(['2', 'Yash', '4'], dtype='<U4')

# %%
new_array = array.astype(np.int64)
new_array
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 new_array = array.astype(np.int64)
#       2 new_array
#
# ValueError: invalid literal for int() with base 10: np.str_('Yash')

# %%
new_array2 = array.astype(np.float64)
new_array2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 new_array2 = array.astype(np.float64)
#       2 new_array2
#
# ValueError: could not convert string to float: np.str_('Yash')

# %%
# we cann't convert a String to INT or FLOAT

# %%
array = np.array([[1,2,3],[4,5,6]])
array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
array.ndim # to check dimension of an array
# Out:
# 2

# %%
array.shape # to check shape of an array
# Out:
# (2, 3)

# %%
array.size # to check size of an array
# Out:
# 6

# %%
array.itemsize
# Out:
# 8
