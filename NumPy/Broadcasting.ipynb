# %%
import numpy as np

# %% [markdown]
# # broadcasting means stracting the shape of smaller arrays , so that they match the shape of bigger arrays

# %%
image = np.array([[200,500],
                  [300,600]])
brightness = image + 50 
brightness
# Out:
# array([[250, 550],
#        [350, 650]])

# %%
image.shape
# Out:
# (2, 2)

# %% [markdown]
# Broadcasting works if:
#
# 1. Compare from right to left
#
# 2. Dimensions must be:
#
# 3. Equal, OR
#
# 4. One of them must be 1
#
# 5. Missing dimensions are treated as 1
#
# 6. If none of these satisfied → ❌ ValueError
#
# 🧠 Memory Trick
#
# 👉 “Right to left, equal or 1 — otherwise done.”
