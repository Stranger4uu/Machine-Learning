# %%
import pandas as pd
import numpy as np

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Alice'],
#  'Age': [25, 30, 35, nan, 29, 25],
#  'Department': ['HR', 'IT', 'Finance', 'IT', 'HR', 'HR'],
#  'Salary': [50000, 60000, 70000, 62000, nan, 50000]}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
df["Hiked Salary"] = df["Salary"] * 2
df
# Out:
#       Name   Age Department   Salary  Hiked Salary
# 0    Alice  25.0         HR  50000.0      100000.0
# 1      Bob  30.0         IT  60000.0      120000.0
# 2  Charlie  35.0    Finance  70000.0      140000.0
# 3    David   NaN         IT  62000.0      124000.0
# 4      Eve  29.0         HR      NaN           NaN
# 5    Alice  25.0         HR  50000.0      100000.0

# %%
df["Hiked Salary"] = df["Hiked Salary"].apply(lambda x: x / 5
if x > 100000.0 else x)
df
# Out:
#       Name   Age Department   Salary  Hiked Salary
# 0    Alice  25.0         HR  50000.0      100000.0
# 1      Bob  30.0         IT  60000.0       12000.0
# 2  Charlie  35.0    Finance  70000.0       14000.0
# 3    David   NaN         IT  62000.0       12400.0
# 4      Eve  29.0         HR      NaN           NaN
# 5    Alice  25.0         HR  50000.0      100000.0

# %%
#using str.split() ,we can split the string data

# %%
# apply and lambda

# %%
def multiplying_age(x):
    return x*2
df["Age"] = df["Age"].apply(multiplying_age)

# %%
df
# Out:
#       Name   Age Department   Salary  Hiked Salary
# 0    Alice  50.0         HR  50000.0      100000.0
# 1      Bob  60.0         IT  60000.0       12000.0
# 2  Charlie  70.0    Finance  70000.0       14000.0
# 3    David   NaN         IT  62000.0       12400.0
# 4      Eve  58.0         HR      NaN           NaN
# 5    Alice  50.0         HR  50000.0      100000.0

# %%
df["Age"] = df["Age"].apply(lambda x: x/2)

# %%
df
# Out:
#       Name   Age Department   Salary  Hiked Salary
# 0    Alice  25.0         HR  50000.0      100000.0
# 1      Bob  30.0         IT  60000.0       12000.0
# 2  Charlie  35.0    Finance  70000.0       14000.0
# 3    David   NaN         IT  62000.0       12400.0
# 4      Eve  29.0         HR      NaN           NaN
# 5    Alice  25.0         HR  50000.0      100000.0
