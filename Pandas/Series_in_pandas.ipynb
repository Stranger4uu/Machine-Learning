# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30, 40, 50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s1 = pd.Series([10, 20, 30, 40, 50, "Yash"])
s1
# Out:
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50
# 5    Yash
# dtype: object

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name = "Numbers"
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %%
print(s.name)
# Out:
# Numbers
